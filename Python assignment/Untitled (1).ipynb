# %%
# ##Using Get Method
# fname = input("Enter the File Name:")
# try:
#     fhand = open(fname)
#     d1 = dict()
#     for line in fhand:
#         words = line.split()
#         for word in words:
#             d1[word] = d1.get(word, 0) + 1 
#     print(d1)
# except:
#     print("File not found")

# fname = input("Enter the File Name:")
# try:
#     fhand=open(fname)
#     d1 = dict()
#     for line in fhand:
#         words = line.split()
#         for word in words:
#             if word in d1:
#                 d1[word] = d1[word] + 1
#             else:
#                     d1[word] = 1
#     print(d1)
    
# except:
#     print("File not found")
# Out:
# Enter the File Name: my file.txt
# {'it': 10, 'was': 10, 'the': 10, 'best': 1, 'of': 11, 'times,': 2, 'worst': 1, 'age': 2, 'wisdom,': 1, 'foolishness,': 1, 'epoch': 2, 'belief,': 1, 'incredulity,': 1, 'season': 2, 'light,': 1, 'darkness,': 1, 'spring': 1, 'hope,': 1, 'winter': 1, 'despair.': 1, '(Charles': 1, 'Dickens,': 1, 'A': 1, 'Tale': 1, 'Two': 1, 'Cities)': 1}
